# %% [markdown]
# ## Processing Ocean Color Imagery - Process Micasense Images

# %% [markdown]
# Pull in all images and process with micasense tools
#     normalize and align and whatnot
#     put these into functions and clean up
#     also visualize along the way and look at distributions to think about whether or not they're legitimate
#     write out
#
# Pull in all images as modified and metadata with specific functions
#     Visualize for issues and shadows and bright spots and locations
#     correct for sky radiance
#     visualize the distributions of both sky (clouds) and sea
#     look at the variability of spectra both for specific pixels and across nearby images
#     filter for orientation and location and issues
#
# take the water leaving spectra and convert to chla as well as other future products and just intro general analysis of spectra
#     produce a csv or .shp or images of ocean color products

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ipywidgets import FloatProgress, Layout
from IPython.display import display
from micasense import imageset as imageset
from micasense import capture as capture
import multiprocessing
import glob, shutil, os

import cv2
import numpy as np
import matplotlib.pyplot as plt


import micasense.imageutils as imageutils
import micasense.plotutils as plotutils

import exiftool
import datetime

import subprocess
import math

from utils import *
from georeg import *

# %%
project_name = '210828_A2_dyefrontcross2'

# %% [markdown]
# Inspect the Exposure, gain, DLS

# %%
surface_dir = os.path.join('data', project_name, 'sea')

# %%
imgset = imageset.ImageSet.from_directory(surface_dir)

# %%
dls_ed = []
exposures = []
gains = []
for cap in imgset.captures:
    if len(cap.dls_irradiance()) == 6:
        dls_ed.append(np.array(cap.dls_irradiance()))
        exp = []
        gain_cap = []
        for img in cap.images: 
            exp.append(img.exposure_time)
            gain_cap.append(img.gain)
        exposures.append(exp)
        gains.append(gain_cap)
        
exposures = np.array(exposures)
gains = np.array(gains)
dls_ed = np.array(dls_ed)

# %%
band_names = ['blue', 'green', 'red', 'nir', 'red edge']

fig, ax = plt.subplots(5,1, figsize=(12,18))

for i in range(5):
    ax[i].plot(exposures[100:280,i], color='green')
#     ax[i].set_ylim(0,.002)
    ax2 = ax[i].twinx()
    ax2.plot(gains[100:280,i], color='blue')
#     ax2.set_ylim(0,8.2)
    ax3 = ax[i].twinx()
    ax3.plot(dls_ed[100:280,i], color='red')
#     ax3.set_ylim(.22,.5)
    ax3.spines['right'].set_position(('outward', 60))
    
    ax[i].set_ylabel('exposure')
    ax2.set_ylabel('gain')
    ax3.set_ylabel('DLS Reading')
    
    ax[i].yaxis.label.set_color('green')
    ax2.yaxis.label.set_color('blue')
    ax3.yaxis.label.set_color('red')
    
    ax[i].set_title(band_names[i])
    fig.tight_layout()
#     fig.savefig('gain_exposure_dls.png',dpi=300)
    fig.show()
#
# Out:
# /home/clifgray/anaconda3/envs/micasense/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /home/clifgray/anaconda3/envs/micasense/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /home/clifgray/anaconda3/envs/micasense/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /home/clifgray/anaconda3/envs/micasense/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /home/clifgray/anaconda3/envs/micasense/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ### Run the process

# %%
! ls data/210827_A2_frontcross2/
# Out:
# 0000SET  RedEdge  SYNLog-19-08-13_27-08-2021.csv

# %% [markdown]
# ### This is the typical full workflow

# %%
glob.glob(os.path.join('data', project_name, 'panel', 'IMG_0003*.tif'))
# Out:
# ['data/210828_A2_dyefrontcross2/panel/IMG_0003_3.tif',
#  'data/210828_A2_dyefrontcross2/panel/IMG_0003_5.tif',
#  'data/210828_A2_dyefrontcross2/panel/IMG_0003_2.tif',
#  'data/210828_A2_dyefrontcross2/panel/IMG_0003_1.tif',
#  'data/210828_A2_dyefrontcross2/panel/IMG_0003_6.tif',
#  'data/210828_A2_dyefrontcross2/panel/IMG_0003_4.tif']

# %% [markdown]
# #### First process the Altum images

# %% [markdown]
# From https://support.micasense.com/hc/en-us/articles/360025336894-Using-Panels-and-or-DLS-in-Post-Processing
#
# In the case of a clear, sunny day, we recommend using only the calibration panels. Light sensor data will not be as effective and so should generally not be used in this case.
#
# Light sensor data is most effective in overcast, completely cloudy conditions. In this case, we would recommend using both light sensor and panel data for calibration.

# %%
# to use the DLS and not the panel set this to None
# panelNames = None
panelNames = glob.glob(os.path.join('data', project_name, 'panel', 'IMG_0003*.tif'))

warp_img_dir = os.path.join('data', project_name, 'sea', 'align_img')
surface_out = process_micasense_subset(surface_dir, panelNames, warp_img_dir, overwrite=False)
# Out:
# Panel irradiance calculated.
# used warp dir data/210828_A2_dyefrontcross2/sea/align_img
# Aligning images. Depending on settings this can take from a few seconds to many minutes
# Finished aligning band 0
# Finished aligning band 1
# Finished aligning band 2
# Finished aligning band 3
# Finished aligning band 4
# Saving time: 0:18:27.342645
# Alignment+Saving rate: 0.26 images per second
# Finished saving images.
# exiftool -csv="data/210828_A2_dyefrontcross2/sea/stacks/log.csv" -overwrite_original data/210828_A2_dyefrontcross2/sea/stacks
# Finished saving image metadata.

# %%
! exiftool -csv="data/210828_A2_dyefrontcross2/sea/stacks/log.csv" -overwrite_original data/210828_A2_dyefrontcross2/sea/stacks
# Out:
#     1 directories scanned
#   288 image files updated

# %% [markdown]
# #### Now process the RedEdge Images
#
# Need to ensure these are the correct images via time. They do seem correct.
#
# Also note that the first couple sea images were bad because of spray and glint and shadow.

# %%
panelNames = glob.glob(os.path.join('data', project_name, 'RedEdge', 'panel', 'IMG_0000*.tif'))
panelNames
# Out:
# ['data/210828_A2_dyefrontcross2/RedEdge/panel/IMG_0000_4.tif',
#  'data/210828_A2_dyefrontcross2/RedEdge/panel/IMG_0000_1.tif',
#  'data/210828_A2_dyefrontcross2/RedEdge/panel/IMG_0000_2.tif',
#  'data/210828_A2_dyefrontcross2/RedEdge/panel/IMG_0000_5.tif',
#  'data/210828_A2_dyefrontcross2/RedEdge/panel/IMG_0000_3.tif']

# %%
# to use the DLS and not the panel set this to None
#panelNames = None
panelNames = glob.glob(os.path.join('data', project_name, 'RedEdge', 'panel', 'IMG_0000*.tif'))

blocked_dir = os.path.join('data', project_name, 'RedEdge', 'tube')
sky_dir = os.path.join('data', project_name, 'RedEdge', 'sky')
surface_dir = os.path.join('data', project_name, 'RedEdge', 'sea')

warp_img_dir = os.path.join('data', project_name, 'RedEdge', 'tube')
sunlight_blocked_out = process_micasense_subset(blocked_dir, panelNames, warp_img_dir, overwrite=False)

warp_img_dir = os.path.join('data', project_name, 'RedEdge', 'sky')
sky_out = process_micasense_subset(sky_dir, panelNames, warp_img_dir, overwrite=False)

warp_img_dir = os.path.join('data', project_name, 'RedEdge', 'sea')
surface_out = process_micasense_subset(surface_dir, panelNames, warp_img_dir, overwrite=False)
# Out:
# Panel irradiance calculated.
# used warp dir data/210828_A2_dyefrontcross2/RedEdge/tube
# Aligning images. Depending on settings this can take from a few seconds to many minutes
# Finished aligning band 0
# Finished aligning band 3
# Finished aligning band 1
# Finished aligning band 2
# Finished aligning band 4
# Saving time: 0:00:16.405573
# Alignment+Saving rate: 0.73 images per second
# Finished saving images.
# exiftool -csv="data/210828_A2_dyefrontcross2/RedEdge/tube/stacks/log.csv" -overwrite_original data/210828_A2_dyefrontcross2/RedEdge/tube/stacks
# Finished saving image metadata.
# Panel irradiance calculated.
# used warp dir data/210828_A2_dyefrontcross2/RedEdge/sky
# Aligning images. Depending on settings this can take from a few seconds to many minutes
# Finished aligning band 0
# Finished aligning band 4
# Finished aligning band 3
# Finished aligning band 1
# Finished aligning band 2
# Saving time: 0:00:03.419420
# Alignment+Saving rate: 0.88 images per second
# Finished saving images.
# exiftool -csv="data/210828_A2_dyefrontcross2/RedEdge/sky/stacks/log.csv" -overwrite_original data/210828_A2_dyefrontcross2/RedEdge/sky/stacks
# Finished saving image metadata.
# Panel irradiance calculated.
# used warp dir data/210828_A2_dyefrontcross2/RedEdge/sea
# Aligning images. Depending on settings this can take from a few seconds to many minutes
# Finished aligning band 0
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/clifgray/anaconda3/envs/micasense/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/clifgray/Code/ocean_color/micasense/imageutils.py", line 163, in align
#     cc, warp_matrix = cv2.findTransformECC(grad1, grad2, warp_matrix, warp_mode, criteria, inputMask=None, gaussFiltSize=1)
# cv2.error: OpenCV(4.1.2) ../modules/video/src/ecc.cpp:572: error: (-7:Iterations do not converge) The algorithm stopped before its convergence. The correlation is going to be minimized. Images may be uncorrelated or non-overlapped in function 'findTransformECC'
#
# """
#
# The above exception was the direct cause of the following exception:
#
# error                                     Traceback (most recent call last)
# <ipython-input-22-9baf94e0760d> in <module>
#      14
#      15 warp_img_dir = os.path.join('data', project_name, 'RedEdge', 'sea')
# ---> 16 surface_out = process_micasense_subset(surface_dir, panelNames, warp_img_dir, overwrite=False)
#
# ~/Code/ocean_color/utils.py in process_micasense_subset(img_dir, panelNames, warp_img_dir, overwrite, panelCorners)
#     220     thumbnailPath = os.path.join(img_dir, 'thumbnails')
#     221
# --> 222     if save_images(imgset, outputPath, thumbnailPath, panel_irradiance, warp_img_capture, overwrite=overwrite) == True:
#     223         print("Finished saving images.")
#     224         fullCsvPath = write_exif_csv(imgset, outputPath)
#
# ~/Code/ocean_color/utils.py in save_images(img_set, outputPath, thumbnailPath, panel_irradiance, warp_img_capture, generateThumbnails, overwrite)
#     142     # you need a relatively flat image and it should be at the same altitude
#     143     # see https://github.com/micasense/imageprocessing/blob/de96aad06fc32a35597a8264190f81cd35206383/Alignment.ipynb
# --> 144     warp_matrices = get_warp_matrix(warp_img_capture)
#     145
#     146     if not os.path.exists(outputPath):
#
# ~/Code/ocean_color/utils.py in get_warp_matrix(img_capture, max_alignment_iterations)
#      66                                                               max_iterations = max_alignment_iterations,
#      67                                                               warp_mode = warp_mode,
# ---> 68                                                               pyramid_levels = pyramid_levels)
#      69
#      70     #print("Finished Aligning, warp matrices={}".format(warp_matrices))
#
# ~/Code/ocean_color/micasense/imageutils.py in align_capture(capture, ref_index, warp_mode, max_iterations, epsilon_threshold, multithreaded, debug, pyramid_levels)
#     231     if(multithreaded):
#     232         pool = multiprocessing.Pool(processes=multiprocessing.cpu_count())
# --> 233         for _,mat in enumerate(pool.imap_unordered(align, alignment_pairs)):
#     234             warp_matrices[mat['match_index']] = mat['warp_matrix']
#     235             print("Finished aligning band {}".format(mat['match_index']))
#
# ~/anaconda3/envs/micasense/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     746         if success:
#     747             return value
# --> 748         raise value
#     749
#     750     __next__ = next                    # XXX
#
# ~/anaconda3/envs/micasense/lib/python3.7/multiprocessing/pool.py in worker()
#     119         job, i, func, args, kwds = task
#     120         try:
# --> 121             result = (True, func(*args, **kwds))
#     122         except Exception as e:
#     123             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/Code/ocean_color/micasense/imageutils.py in align()
#     161
#     162             try:
# --> 163                 cc, warp_matrix = cv2.findTransformECC(grad1, grad2, warp_matrix, warp_mode, criteria, inputMask=None, gaussFiltSize=1)
#     164             except TypeError:
#     165                 cc, warp_matrix = cv2.findTransformECC(grad1, grad2, warp_matrix, warp_mode, criteria)
#
# error: OpenCV(4.1.2) ../modules/video/src/ecc.cpp:572: error: (-7:Iterations do not converge) The algorithm stopped before its convergence. The correlation is going to be minimized. Images may be uncorrelated or non-overlapped in function 'findTransformECC'

# %%
! exiftool -csv="data/210828_A2_dyefrontcross2/RedEdge/tube/stacks/log.csv" -overwrite_original data/210828_A2_dyefrontcross2/RedEdge/tube/stacks
# Out:
#     1 directories scanned
#    12 image files updated

# %%
! exiftool -csv="data/210828_A2_dyefrontcross2/RedEdge/sky/stacks/log.csv" -overwrite_original data/210828_A2_dyefrontcross2/RedEdge/sky/stacks
# Out:
#     1 directories scanned
#     3 image files updated

# %%
! exiftool -csv="data/210827_A1_frontcross1/RedEdge/sea/stacks/log.csv" -overwrite_original data/210827_A1_frontcross1/RedEdge/sea/stacks
# Out:
#     1 directories scanned
#     3 image files updated
